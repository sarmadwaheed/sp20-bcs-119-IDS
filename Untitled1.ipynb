# %%
import folium
import pandas as pd
pakistan_map = folium.Map(location = [30.37,69.34], zoom_start=4.5, tiles='OpenStreetMap')
import csv

# from google.colab import drive
# drive.mount('/content/drive')

df = pd.read_csv(r'/content/Data.csv')
df

t = 0
for c in df['Total Cases']:
  t = int(c) + int(t)
for state,lat,long,tc,de,re,ac in zip(list(df['City']),list(df['Latitude']),list(df['Longitude']),list(df['Total Cases']),list(df['Deaths']),list(df['Recoveries']),list(df['Active Cases'])):
    folium.CircleMarker(location = [lat,long],radius = (tc/t)*100,color = 'red',fill = False,fill_color = 'blue').add_to(pakistan_map)
    xyz = '<strong>City:  ' + state + '</strong><br>' + 'Total Cases: ' + str(tc) + '<br>' + 'Deaths: '+ str(de) + '<br>' + 'Recoveries: ' + str(re) + '<br>' + 'Active Cases: ' + str(ac)
    iframe = folium.IFrame(xyz, width=200, height=150)
    popupData = folium.Popup(iframe, max_width=500)
    folium.Marker(location = [lat,long], popup=popupData).add_to(pakistan_map)
    

pakistan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b0bb830baba3af78c51afd653bf334a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b0bb830baba3af78c51afd653bf334a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0b0bb830baba3af78c51afd653bf334a = L.map(
#                 &quot;map_0b0bb830baba3af78c51afd653bf334a&quot;,
#                 {
#                     center: [30.37, 69.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40b286992b000dbcfa7ef91ac8b9765d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#             var circle_marker_d397d3a58685d893c1b4736f0b072e50 = L.circleMarker(
#                 [24.8607, 67.0011],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 31.372549019607842, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#             var marker_8133c09bdfdfdd52898a854e3f3a47f9 = L.marker(
#                 [24.8607, 67.0011],
#                 {}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#         var popup_8155eb0ef36a1edb8799089e7b4579f1 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_c7e555b98ea29592ec71ba466909b86a = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkNpdHk6ICBLYXJhY2hpPC9zdHJvbmc+PGJyPlRvdGFsIENhc2VzOiA0MDAwMDxicj5EZWF0aHM6IDEyMDA8YnI+UmVjb3ZlcmllczogMjgwMDA8YnI+QWN0aXZlIENhc2VzOiA3ODA=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_8155eb0ef36a1edb8799089e7b4579f1.setContent(i_frame_c7e555b98ea29592ec71ba466909b86a);
#
#
#         marker_8133c09bdfdfdd52898a854e3f3a47f9.bindPopup(popup_8155eb0ef36a1edb8799089e7b4579f1)
#         ;
#
#
#
#
#             var circle_marker_aa25082e8dd9582adfca85d9efcd733d = L.circleMarker(
#                 [27.7244, 68.8228],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 17.254901960784313, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#             var marker_462ac992618916fd82985d630a14572f = L.marker(
#                 [27.7244, 68.8228],
#                 {}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#         var popup_68422d46a6b07f18747294babe1b648c = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_e42c954a483713b5a599d81c872a719c = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkNpdHk6ICBTdWtrdXI8L3N0cm9uZz48YnI+VG90YWwgQ2FzZXM6IDIyMDAwPGJyPkRlYXRoczogODAwPGJyPlJlY292ZXJpZXM6IDIxMjAwPGJyPkFjdGl2ZSBDYXNlczogNDMw&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_68422d46a6b07f18747294babe1b648c.setContent(i_frame_e42c954a483713b5a599d81c872a719c);
#
#
#         marker_462ac992618916fd82985d630a14572f.bindPopup(popup_68422d46a6b07f18747294babe1b648c)
#         ;
#
#
#
#
#             var circle_marker_0d74b18c3041513783b80d1cccff8df0 = L.circleMarker(
#                 [27.93677, 69.31941],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.686274509803921, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#             var marker_c048594f6531dfa00535652d8993c456 = L.marker(
#                 [27.93677, 69.31941],
#                 {}
#             ).addTo(map_0b0bb830baba3af78c51afd653bf334a);
#
#
#         var popup_5d8507e72b8dfe36712a63f1c1400e9b = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_15e812c9a80940e
